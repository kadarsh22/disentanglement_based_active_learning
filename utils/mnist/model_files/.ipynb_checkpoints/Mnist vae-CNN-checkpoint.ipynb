# %%
import numpy as np
import torch
from torch.autograd import Variable
import torch.nn.functional as F
from early_stopping import EarlyStopping
import torchvision
import torchvision.transforms as transforms
import torchvision.datasets as dsets
import torch.nn as nn
from Custom_Dataset import NewDataset

from lenet import Lenet
from vae import VAE
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
full_cnn_model = Lenet()
full_cnn_model.load_state_dict(torch.load('../trained_models/cnn_lenet_28_sigmoid.pt',map_location='cuda:0'))
full_cnn_model.eval()
full_cnn_model.to(device)
# Out:
# Lenet(
#   (cnn1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (maxpool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (cnn2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu): ReLU()
#   (tanh): Tanh()
#   (dropout): Dropout(p=0.8)
#   (fc1): Linear(in_features=3136, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=10, bias=True)
# )

# %%
Model = VAE(nz=20,device=device)

# %%
Model.load_state_dict(torch.load('../trained_models/trained_vae'))

# %%
z = torch.randn(60000,20)

# %%
images = Model.decode(z)

# %%
images.shape
# Out:
# torch.Size([1000, 1, 28, 28])

# %%
torch.save(images,'../data_gan/vaetrain_data')

# %%
images = torch.load('../data_gan/vaetrain_data')

# %%
mnist_wgan_loader = list(torch.split(images.to(device),1000))

# %%
len(mnist_wgan_loader)
# Out:
# 60

# %%
labels_list = []
for images in mnist_wgan_loader:
    out = F.softmax(full_cnn_model(images),dim=1)
    _,labels = torch.max(out.data.cpu(), 1)
    labels_list.append(labels)

# %%
labels =  torch.stack(labels_list)

# %%
labels = labels.view(-1)

# %%
images.shape
# Out:
# torch.Size([60000, 1, 28, 28])

# %%
labels.shape
# Out:
# torch.Size([60000])

# %%
torch.save(images,'../data_gan/vaelabels')

# %%
grid_img = torchvision.utils.make_grid(images[:50].detach().cpu(), nrow= 10)
plt.imshow(grid_img.permute(1, 2, 0))
plt.show()
labels[:50]
# Out:
# tensor([6, 7, 7, 9, 9, 6, 9, 9, 0, 8, 5, 0, 7, 7, 6, 8, 7, 8, 0, 8, 6, 5, 8, 8,
#         3, 5, 3, 7, 7, 6, 9, 6, 3, 9, 9, 2, 1, 8, 2, 3, 3, 3, 6, 4, 8, 9, 1, 9,
#         1, 8])

# %%
labels.shape
# Out:
# torch.Size([60000])

# %%
transform = transforms.Compose([transforms.ToTensor()])
train_dataset = NewDataset(images,labels)
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=100, shuffle=True)
test_dataset = dsets.MNIST(root='./newminst_wgan', 
                           train=False, 
                           transform=transform,download=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset, 
                                          batch_size=100, 
                                          shuffle=False)

# %%
seed = 22
torch.backends.cudnn.deterministic = True
torch.manual_seed(seed )
torch.cuda.manual_seed(seed )
np.random.seed(seed)

# %%
full_cnn_model = Lenet()
full_cnn_model.to(device)

criterion = nn.CrossEntropyLoss()
learning_rate = 0.001
optimizer = torch.optim.Adam(full_cnn_model.parameters(), lr=learning_rate)

# %%
for epoch in range(60):
    train_loss_list = []
    test_loss_list = []

    full_cnn_model.train()
    for i, (images, labels) in enumerate(train_loader):
        images = Variable(images).to(device)
        labels = Variable(labels).to(device)
        optimizer.zero_grad()
        outputs = full_cnn_model (images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        train_loss_list.append(loss.item())
    
    full_cnn_model.eval()
    accuracy_list = []
    for i, (images, labels) in enumerate(test_loader):
        images = Variable(images).to(device)
        labels = Variable(labels).to(device)
        outputs = full_cnn_model(images)
        loss = criterion(outputs, labels)
        _, predicted = torch.max(outputs.data, 1)
        total = labels.size(0)
        correct = (predicted == labels).sum()
        accuracy = 100 * (float(correct) /float( total))
        accuracy_list.append(accuracy)
        test_loss_list.append(loss.item())
    final_accuracy = sum(accuracy_list)/len(accuracy_list)
    traininig_loss = sum(train_loss_list)/len(train_loss_list)
    testing_loss = sum(test_loss_list)/len(test_loss_list)
    print('Epoch: {}. TrainLoss: {}. TestLoss: {}. Accuracy: {}'.format(epoch, traininig_loss,testing_loss, final_accuracy))
# Out:
# Epoch: 0. TrainLoss: 0.9162392870585123. TestLoss: 0.1216583781898953. Accuracy: 96.15
# Epoch: 1. TrainLoss: 0.49827980148295564. TestLoss: 0.09459259781287983. Accuracy: 96.84
# Epoch: 2. TrainLoss: 0.4279661216586828. TestLoss: 0.08991792882152368. Accuracy: 97.07
# Epoch: 3. TrainLoss: 0.38673301686843237. TestLoss: 0.08555922402214491. Accuracy: 97.5
# Epoch: 4. TrainLoss: 0.3622164091467857. TestLoss: 0.07652493641973707. Accuracy: 97.47
# Epoch: 5. TrainLoss: 0.34923029102385045. TestLoss: 0.07477528539151536. Accuracy: 97.84
# Epoch: 6. TrainLoss: 0.33744048528373244. TestLoss: 0.0763345423444116. Accuracy: 97.73
# Epoch: 7. TrainLoss: 0.32480451203882693. TestLoss: 0.07541897932314896. Accuracy: 97.81
# Epoch: 8. TrainLoss: 0.3129293918485443. TestLoss: 0.07190646338291116. Accuracy: 97.82
# Epoch: 9. TrainLoss: 0.31053586474309364. TestLoss: 0.06708289709218661. Accuracy: 97.98
# Epoch: 10. TrainLoss: 0.3035847189153234. TestLoss: 0.07133103667059913. Accuracy: 97.9
# Epoch: 11. TrainLoss: 0.3000386315087477. TestLoss: 0.07252785003249301. Accuracy: 97.92
# Epoch: 12. TrainLoss: 0.292496701143682. TestLoss: 0.06860240844202053. Accuracy: 98.06
# Epoch: 13. TrainLoss: 0.28631252139806745. TestLoss: 0.07258858038090693. Accuracy: 98.03
# Epoch: 14. TrainLoss: 0.2845046888043483. TestLoss: 0.07391330095691956. Accuracy: 98.08
# Epoch: 15. TrainLoss: 0.28111438353856405. TestLoss: 0.06966344621090684. Accuracy: 98.01
# Epoch: 16. TrainLoss: 0.27545595900466047. TestLoss: 0.07031349062832305. Accuracy: 98.14
# Epoch: 17. TrainLoss: 0.27177985007564226. TestLoss: 0.07153692338761175. Accuracy: 98.08
# Epoch: 18. TrainLoss: 0.27206096657862266. TestLoss: 0.06768589875915496. Accuracy: 98.01
# Epoch: 19. TrainLoss: 0.2718498742952943. TestLoss: 0.07053284437264665. Accuracy: 97.97
# Epoch: 20. TrainLoss: 0.2661100137482087. TestLoss: 0.07611852711910615. Accuracy: 98.04
# Epoch: 21. TrainLoss: 0.26069297682493925. TestLoss: 0.07116095435536408. Accuracy: 98.19
# Epoch: 22. TrainLoss: 0.26314276713877915. TestLoss: 0.07136464770606836. Accuracy: 98.05
# Epoch: 23. TrainLoss: 0.2617876955556373. TestLoss: 0.06888288920759805. Accuracy: 98.1
# Epoch: 24. TrainLoss: 0.25870563740531605. TestLoss: 0.07322376518888632. Accuracy: 98.03
# Epoch: 25. TrainLoss: 0.25876169609526795. TestLoss: 0.079093463607569. Accuracy: 97.9
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-65-31ebfa513b77> in <module>
#      16     full_cnn_model.eval()
#      17     accuracy_list = []
# ---> 18     for i, (images, labels) in enumerate(test_loader):
#      19         images = Variable(images).to(device)
#      20         labels = Variable(labels).to(device)
#
# ~/miniconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     613         if self.num_workers == 0:  # same-process loading
#     614             indices = next(self.sample_iter)  # may raise StopIteration
# --> 615             batch = self.collate_fn([self.dataset[i] for i in indices])
#     616             if self.pin_memory:
#     617                 batch = pin_memory_batch(batch)
#
# ~/miniconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py in <listcomp>(.0)
#     613         if self.num_workers == 0:  # same-process loading
#     614             indices = next(self.sample_iter)  # may raise StopIteration
# --> 615             batch = self.collate_fn([self.dataset[i] for i in indices])
#     616             if self.pin_memory:
#     617                 batch = pin_memory_batch(batch)
#
# ~/miniconda3/lib/python3.6/site-packages/torchvision/datasets/mnist.py in __getitem__(self, index)
#      75
#      76         if self.transform is not None:
# ---> 77             img = self.transform(img)
#      78
#      79         if self.target_transform is not None:
#
# ~/miniconda3/lib/python3.6/site-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      47     def __call__(self, img):
#      48         for t in self.transforms:
# ---> 49             img = t(img)
#      50         return img
#      51
#
# ~/miniconda3/lib/python3.6/site-packages/torchvision/transforms/transforms.py in __call__(self, pic)
#      74             Tensor: Converted image.
#      75         """
# ---> 76         return F.to_tensor(pic)
#      77
#      78     def __repr__(self):
#
# ~/miniconda3/lib/python3.6/site-packages/torchvision/transforms/functional.py in to_tensor(pic)
#      81     img = img.transpose(0, 1).transpose(0, 2).contiguous()
#      82     if isinstance(img, torch.ByteTensor):
# ---> 83         return img.float().div(255)
#      84     else:
#      85         return img
#
# KeyboardInterrupt:
